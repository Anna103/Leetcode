# %%
import string
class Cost_Finder:
    def find_cost(self, number_of_testcases, cost_of_letters, total_cost_required):
        list_of_alphabets = list(string.ascii_lowercase)
        dict_of_letters_costs = dict()
        i = 0
        for cha in list_of_alphabets:
            dict_of_letters_costs[cha] = cost_of_letters[i]
            i += 1
        
        def combo(ans, current_cost, alpha_list, l):
            if current_cost == total_cost_required:
                return ans
            for i in range(l, -1, -1):
                if(current_cost + dict_of_letters_costs[alpha_list[i]] <= total_cost_required):
                    return combo(ans+alpha_list[i], current_cost+dict_of_letters_costs[alpha_list[i]], alpha_list, i)
            return combo(ans[:-1], current_cost - dict_of_letters_costs[ans[-1]], alpha_list, alpha_list.index(ans[-1])-1)
                
        return combo("z", cost_of_letters[-1], list_of_alphabets, len(list_of_alphabets)-1)

# %%
if __name__ == "__main__":
    cf = Cost_Finder()
    number_of_testcases = 1
    #cost_of_letters = [1 for i in range(24)]
    #cost_of_letters = [1, 1, 2, 33, 4, 6, 9, 7, 36, 12, 58, 32, 28, 994, 22, 255, 47, 69, 558, 544, 21, 36, 48, 85, 48, 58]
    #total_cost_required = 236
    #cost_of_letters = [252, 888, 578, 746, 295, 884, 198, 655, 503, 868, 942, 506, 718, 498, 727, 338, 43, 768, 783, 312, 369, 712, 230, 106, 102, 554]
    #total_cost_required = 6674
    
    #cost_of_letters = [545, 941, 849, 921, 459, 316, 606, 932, 506, 311, 964, 766, 626, 419, 50, 137, 79, 900, 340, 81, 277, 815, 250, 183, 862, 825]
    #total_cost_required = 8976
    
    cost_of_letters = [545, 941, 849, 921, 459, 316, 606, 932, 506, 311, 964, 766, 626, 419, 50, 137, 79, 900, 340, 81, 277, 815, 250, 183, 862, 825]
    total_cost_required = 862
    
    
    print(cf.find_cost(number_of_testcases, cost_of_letters, total_cost_required))
# Out:
# y

# %%
if __name__ == "__main__":
    cf = Cost_Finder()
    number_of_testcases = 1
    cost_of_letters = [1, 1, 2, 33, 4, 6, 9, 7, 36, 12, 58, 32, 28, 994, 22, 255, 47, 69, 558, 544, 21, 36, 48, 85, 48, 58]
    total_cost_required = 236
    print(cf.find_cost(number_of_testcases, cost_of_letters, total_cost_required))
# Out:
# a

# %%
s =["zze", "zy"]
print(sorted(s))
# Out:
# ['zy', 'zze']

# %%
for i in range(len_of_alpha_list, -1, -1):
                if(current_cost + dict_of_letters_costs[alpha_list[i]] > total_cost_required):
                    if(l >= 0):
                        return combo(ans[:-1], current_cost-dict_of_letters_costs[ans[-1]], alpha_list, l-1, len_of_alpha_list)
                    return combo(ans[1:], current_cost-dict_of_letters_costs[ans[0]], len_of_alpha_list-1, len_of_alpha_list-1)
                return combo(ans+alpha_list[i], current_cost+dict_of_letters_costs[alpha_list[i]], alpha_list, l, len_of_alpha_list)

# %%
# Python 3 implementation of the approach 
  
# Function to find all unique combination of 
# given elements such that their sum is K 
def unique_combination(l, sum, K, local, A): 
      
    # If a unique combination is found 
    if (sum == K): 
        print("{", end = "") 
        for i in range(len(local)): 
            if (i != 0): 
                print(" ", end ="") 
            print(local[i], end = "") 
            if (i != len(local) - 1): 
                print(", ", end = "") 
        print("}") 
        return
  
    # For all other combinations 
    for i in range(l, len(A), 1): 
          
        # Check if the sum exceeds K 
        if (sum + A[i] > K): 
            continue
  
        # Check if it is repeated or not 
        if (i == 1 and 
            A[i] == A[i - 1] and i > l): 
            continue
  
        # Take the element into the combination 
        local.append(A[i]) 
  
        # Recursive call 
        unique_combination(i + 1, sum + A[i],  
                                K, local, A) 
  
        # Remove element from the combination 
        local.remove(local[len(local) - 1]) 
  
# Function to find all combination 
# of the given elements 
def Combination(A, K): 
      
    # Sort the given elements 
    A.sort(reverse = False) 
  
    local = [] 
  
    unique_combination(0, 0, K, local, A) 
  
# Driver code 
if __name__ == '__main__': 
    A = [1, 1, 2, 33, 4, 6, 9, 7, 36, 12, 58, 32, 28, 994, 22, 255, 47, 69, 558, 544, 21, 36, 48, 85, 48, 58]
  
    K = 236
  
    # Function call 
    Combination(A, K) 
      
# This code is contributed by 
# Surendra_Gangwar
# Out:
# {1,  1,  2,  4,  6,  7,  9,  12,  21,  22,  28,  32,  33,  58}
# {1,  1,  2,  4,  6,  7,  9,  12,  21,  22,  28,  32,  33,  58}
# {1,  1,  2,  4,  6,  7,  9,  12,  21,  22,  32,  36,  36,  47}
# {1,  1,  2,  4,  6,  7,  9,  12,  21,  32,  36,  36,  69}
# {1,  1,  2,  4,  6,  7,  9,  12,  21,  32,  36,  47,  58}
# {1,  1,  2,  4,  6,  7,  9,  12,  21,  32,  36,  47,  58}
# {1,  1,  2,  4,  6,  7,  9,  12,  21,  32,  36,  47,  58}
# {1,  1,  2,  4,  6,  7,  9,  12,  21,  32,  36,  47,  58}
# {1,  1,  2,  4,  6,  7,  9,  12,  28,  33,  48,  85}
# {1,  1,  2,  4,  6,  7,  9,  12,  28,  33,  48,  85}
# {1,  1,  2,  4,  6,  7,  9,  21,  22,  32,  36,  47,  48}
# {1,  1,  2,  4,  6,  7,  9,  21,  22,  32,  36,  47,  48}
# {1,  1,  2,  4,  6,  7,  9,  21,  22,  32,  36,  47,  48}
# {1,  1,  2,  4,  6,  7,  9,  21,  22,  32,  36,  47,  48}
# {1,  1,  2,  4,  6,  7,  9,  21,  22,  33,  36,  36,  58}
# {1,  1,  2,  4,  6,  7,  9,  21,  22,  33,  36,  36,  58}
# ...

# %%
def checklist():
    x = ""
    def check2():
        x = "Lemon"
        print("x",x)
        value = None
        value2 = ""
        if True:
            value = 2
            value2 = "Two"
            print(value)
            print(value2)
        print(value)
        print(value2)
    print("x",x)
    check2()

# %%
checklist()
# Out:
# x
# x Lemon
# 2
# Two
# 2
# Two

# %%
s = ["one","one","five"]
print(s)
print(sorted(s))
# Out:
# ['one', 'one', 'five']
# ['five', 'one', 'one']
